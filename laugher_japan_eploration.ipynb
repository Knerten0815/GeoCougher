# %%
import pandas as pd
import os

current_directory = os.getcwd()
print(f"\nCurrent working directory: {current_directory}\n")

path_data_japan = "Datasets/ehehe-corpus"
path_data_south_korea = "Datasets"

filename_japan = os.path.join(path_data_japan, "metadata.csv")
filename_japan_stats = os.path.join(path_data_japan, "stats.csv")
filename_south_korea = os.path.join(path_data_south_korea, "Nonverbal_Vocalization_metadata.json")

data_japan = pd.read_csv(filename_japan, encoding="latin-1")
data_stats_japan = pd.read_csv(filename_japan_stats, encoding="latin-1")
data_south_korea = pd.read_json(filename_south_korea, encoding="latin-1")
# Out:
# Current working directory: /Users/vinni/Desktop/Code/Audio Data Science/GeoCougher

# %%
data_japan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16415 entries, 0 to 16414
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   file_name      16415 non-null  object
#  1   transcription  16283 non-null  object
# dtypes: object(2)
# memory usage: 256.6+ KB

# %%
data_japan.head()
# Out:
#                       file_name    transcription
# 0  data/001ed88f/1/00e60b8a.wav  ããµãµãµã£
# 1  data/001ed88f/1/ea143be4.wav     ãã¯ã¯ã¯
# 2  data/006635cc/1/1111f11f.wav     ãµãµãµã£
# 3  data/006635cc/1/24d50866.wav        ãã¯ã¯
# 4  data/006635cc/1/27b8f117.wav          ã¯ã£!

# %%
data_south_korea.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, sex to class
# Columns: 1419 entries, LAA7 to IIOV
# dtypes: object(1419)
# memory usage: 33.3+ KB

# %%
data_south_korea.head()
# Out:
#                                                    LAA7  \
# sex                                                Male
# age                                                  22
# class  [teeth-chattering, teeth-grinding, lip-smacking]
#
#                                                     MU5F  \
# sex                                               Female
# age                                                   26
# class  [teeth-chattering, tongue-clicking, coughing, ...
#
#                                                     GEUL  \
# sex                                               Female
# age                                                   24
# class  [teeth-chattering, tongue-clicking, lip-smacking]
#
#                                       P4ZA  \
# sex                                   Male
# age                                     19
# class  [teeth-chattering, tongue-clicking]
#
#                                                     M487  \
# sex                                                 Male
# age                                                   25
# class  [teeth-chattering, tongue-clicking, laughing, ...
#
#                                             DY1S  \
# sex                                       Female
# age                                           15
# class  [teeth-chattering, lip-smacking, panting]
#
#                                                     VTPR                R634  \
# sex                                               Female                Male
# age                                                   23                  18
# class  [teeth-chattering, teeth-grinding, nose-blowin...  [teeth-chattering]
#
#                                                     VVBA  \
# sex                                               Female
# age                                                   23
# class  [teeth-chattering, tongue-clicking, sighing, l...
#
#                                                    TOIV  ...        XI94  \
# sex                                              Female  ...        Male
# age                                                  25  ...          26
# class  [teeth-chattering, teeth-grinding, lip-smacking]  ...  [laughing]
#
#              SBWM        4NEJ        H4VA        6IT3        PAC7        P06U  \
# sex          Male      Female      Female      Female      Female      Female
# age            33          16          60          16          15          20
# class  [laughing]  [laughing]  [laughing]  [laughing]  [laughing]  [laughing]
#
#              XFYG        3KFE       IIOV
# sex          Male      Female       Male
# age            28          24         32
# class  [sneezing]  [sneezing]  [moaning]
#
# [3 rows x 1419 columns]
